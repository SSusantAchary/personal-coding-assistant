# %% [markdown]
# ## Install dependencies

# %%
# !pip install PyGithub -q
# !pip install nbformat -q

# %% [markdown]
# # Get all repos
#
# Replace `GH_ACCESS_TOKEN` with your GitHub access token
# - You may want to go ahead without `GH_ACCESS_TOKEN` set. In this case, 60 requests / hour is the rate limit.
# - With `GH_ACCESS_TOKEN` set, the rate limit is 5000 requests / hour.
# - [Reference](https://docs.github.com/en/rest/overview/resources-in-the-rest-api?apiVersion=2022-11-28#rate-limits-for-requests-from-personal-accounts)

# %%
from github import Github


def get_repos(username, access_token=None, include_fork=False):
    """Fetches repositories for a particular GitHub user."""
    g = Github(access_token)
    user = g.get_user(username)

    results = []
    for repo in user.get_repos():
        if repo.fork is False:
            results.append(repo)
        else:
            if include_fork is True:
                results.append(repo)

    return results

# %%
USERNAME = "sayakpaul"  # @param ["sayakpaul", "deep-diver"]
GH_ACCESS_TOKEN = ""

repos = get_repos(USERNAME, GH_ACCESS_TOKEN)

# %%
from pprint import pprint

print(len(repos))
pprint(repos)
# Out:
# 138
# [Repository(full_name="sayakpaul/A-B-testing-with-Machine-Learning"),
#  Repository(full_name="sayakpaul/A-Barebones-Image-Retrieval-System"),
#  Repository(full_name="sayakpaul/Action-Recognition-in-TensorFlow"),
#  Repository(full_name="sayakpaul/AdaMatch-TF"),
#  Repository(full_name="sayakpaul/Adaptive-Gradient-Clipping"),
#  Repository(full_name="sayakpaul/Adventures-in-TensorFlow-Lite"),
#  Repository(full_name="sayakpaul/Adversarial-Examples-in-Deep-Learning"),
#  Repository(full_name="sayakpaul/Aerial-Cactus-Identification"),
#  Repository(full_name="sayakpaul/Age-Detection-of-Indian-Actors"),
#  Repository(full_name="sayakpaul/Age-Detector-API"),
#  Repository(full_name="sayakpaul/Age-Detector-Web-App"),
#  Repository(full_name="sayakpaul/Anagram"),
#  Repository(full_name="sayakpaul/Analysis-of-college-database-of-2017-passouts"),
#  Repository(full_name="sayakpaul/Analytics-Vidhya-Game-of-Deep-Learning-Hackathon"),
#  Repository(full_name="sayakpaul/Applied-Data-Science-w-Python-Specialization"),
#  Repository(full_name="sayakpaul/AV_Identify_Digits"),
#  Repository(full_name="sayakpaul/Barlow-Twins-TF"),
#  Repository(full_name="sayakpaul/Benchmarking-and-MLI-experiments-on-the-Adult-dataset"),
#  Repository(full_name="sayakpaul/BentoML-Explorations"),
#  Repository(full_name="sayakpaul/BERT-for-Mobile"),
#  Repository(full_name="sayakpaul/big_vision_experiments"),
#  Repository(full_name="sayakpaul/BiT-jax2tf"),
#  Repository(full_name="sayakpaul/Blood-Cell-Detection-using-TFOD-API"),
#  Repository(full_name="sayakpaul/Breast-Cancer-Detection-using-Deep-Learning"),
#  Repository(full_name="sayakpaul/cait-tf"),
#  Repository(full_name="sayakpaul/ccd-ahm-2022"),
#  Repository(full_name="sayakpaul/CI-CD-for-Model-Training"),
#  Repository(full_name="sayakpaul/Consistency-Training-with-Supervision"),
#  Repository(full_name="sayakpaul/ConvNeXt-TF"),
#  Repository(full_name="sayakpaul/count-tokens-hf-datasets"),
#  Repository(full_name="sayakpaul/Data-Pipelines-with-TensorFlow-Data-Services-Exercises"),
#  Repository(full_name="sayakpaul/Data-Science-Tweets-Analysis"),
#  Repository(full_name="sayakpaul/DataCamp-blogs"),
#  Repository(full_name="sayakpaul/deit-tf"),
#  Repository(full_name="sayakpaul/Denoised-Smoothing-TF"),
#  Repository(full_name="sayakpaul/deploy-hf-tf-vision-models"),
#  Repository(full_name="sayakpaul/depth_estimation_trainer"),
#  Repository(full_name="sayakpaul/Distributed-Training-in-TensorFlow-2-with-AI-Platform"),
#  Repository(full_name="sayakpaul/DockerML"),
#  Repository(full_name="sayakpaul/dreambooth-keras"),
#  Repository(full_name="sayakpaul/Dual-Deployments-on-Vertex-AI"),
#  Repository(full_name="sayakpaul/E2E-Object-Detection-in-TFLite"),
#  Repository(full_name="sayakpaul/Emotion-Detection-using-Deep-Learning"),
#  Repository(full_name="sayakpaul/EvoNorms-in-TensorFlow-2"),
#  Repository(full_name="sayakpaul/Experiments-on-Fashion-MNIST"),
#  Repository(full_name="sayakpaul/Favorite-Execises-from-Udacity-s-Deep-Learning-Course"),
#  Repository(full_name="sayakpaul/Federated-Learning-Shenanigans"),
#  Repository(full_name="sayakpaul/First_NodeJS_MongoDB"),
#  Repository(full_name="sayakpaul/FloydHub-Anomaly-Detection-Blog"),
#  Repository(full_name="sayakpaul/FloydHub-K_Means-Blog"),
#  Repository(full_name="sayakpaul/FloydHub-Q-Learning-Blog"),
#  Repository(full_name="sayakpaul/FunMatch-Distillation"),
#  Repository(full_name="sayakpaul/GAN-Hacks"),
#  Repository(full_name="sayakpaul/GCP-ML-API-Demos"),
#  Repository(full_name="sayakpaul/GDE-Collaboration"),
#  Repository(full_name="sayakpaul/Generalized-ODIN-TF"),
#  Repository(full_name="sayakpaul/Generating-categories-from-arXiv-paper-titles"),
#  Repository(full_name="sayakpaul/Generating-Word-Cloud-from-DataCamp-Project-Descriptions"),
#  Repository(full_name="sayakpaul/Genpact-Hiring-Hackathon"),
#  Repository(full_name="sayakpaul/Global-Wheat-Detection"),
#  Repository(full_name="sayakpaul/google-ai-pendrive-content"),
#  Repository(full_name="sayakpaul/Grocery-Product-Detection"),
#  Repository(full_name="sayakpaul/hackerearth-hiring-challenge"),
#  Repository(full_name="sayakpaul/Handwriting-Recognizer-in-Keras"),
#  Repository(full_name="sayakpaul/Hello-TensorFlow"),
#  Repository(full_name="sayakpaul/Hibernate_MVC"),
#  Repository(full_name="sayakpaul/instruct-pix2pix-dataset"),
#  Repository(full_name="sayakpaul/Intel-Scene-Classification-challenge"),
#  Repository(full_name="sayakpaul/Kaggle-CareerCon-2019-Notebooks"),
#  Repository(full_name="sayakpaul/keras-convnext-conversion"),
#  Repository(full_name="sayakpaul/Keras-Examples-RandAugment"),
#  Repository(full_name="sayakpaul/keras-xla-benchmarks"),
#  Repository(full_name="sayakpaul/KMeans_Simple"),
#  Repository(full_name="sayakpaul/Knowledge-Distillation-in-Keras"),
#  Repository(full_name="sayakpaul/Learnable-Image-Resizing"),
#  Repository(full_name="sayakpaul/loan-prediction-av"),
#  Repository(full_name="sayakpaul/Malaria-Detection-with-Deep-Learning"),
#  Repository(full_name="sayakpaul/Manning-Phishing-Websites-Detection"),
#  Repository(full_name="sayakpaul/maxim-tf"),
#  Repository(full_name="sayakpaul/Mean_Shift-2D-"),
#  Repository(full_name="sayakpaul/microsoft-malware-prediction-challenge"),
#  Repository(full_name="sayakpaul/MIRNet-TFLite-TRT"),
#  Repository(full_name="sayakpaul/Mixed-Precision-Training-in-tf.keras-2.0"),
#  Repository(full_name="sayakpaul/ml-bootcamp-india-2022"),
#  Repository(full_name="sayakpaul/ML-Bootcamp-Launchpad"),
#  Repository(full_name="sayakpaul/ml-deployment-k8s-fastapi"),
#  Repository(full_name="sayakpaul/MLP-Mixer-CIFAR10"),
#  Repository(full_name="sayakpaul/mlplanner"),
#  Repository(full_name="sayakpaul/MLPMixer-jax2tf"),
#  Repository(full_name="sayakpaul/model-card-generation-hf"),
#  Repository(full_name="sayakpaul/model-soups-text-classification"),
#  Repository(full_name="sayakpaul/Multimodal-Entailment-Baseline"),
#  Repository(full_name="sayakpaul/NALU"),
#  Repository(full_name="sayakpaul/near-dup-parser"),
#  Repository(full_name="sayakpaul/Online_Examination"),
#  Repository(full_name="sayakpaul/Parallel-programming-in-action"),
#  Repository(full_name="sayakpaul/parameter-ensemble-differential-evolution"),
#  Repository(full_name="sayakpaul/Parkinson-s-Disease-Classifier"),
#  Repository(full_name="sayakpaul/Patients-Conversation-Detector"),
#  Repository(full_name="sayakpaul/PAWS-TF"),
#  Repository(full_name="sayakpaul/personal-coding-assistant"),
#  Repository(full_name="sayakpaul/Phishing-Websites-Detection"),
#  Repository(full_name="sayakpaul/Pima_Indian_Diabetes"),
#  Repository(full_name="sayakpaul/portfolio"),
#  Repository(full_name="sayakpaul/probing-vits"),
#  Repository(full_name="sayakpaul/PythonWhat-Experiments"),
#  Repository(full_name="sayakpaul/PyTorch-sklearn-with-skorch"),
#  Repository(full_name="sayakpaul/Reporting-in-SQL-DataCamp-Course-Exercises"),
#  Repository(full_name="sayakpaul/Reproducibility-in-tf.keras-with-wandb"),
#  Repository(full_name="sayakpaul/Restaurant"),
#  Repository(full_name="sayakpaul/Resume-Group-Read-Runs-WnB"),
#  Repository(full_name="sayakpaul/Revisiting-Pooling-in-CNNs"),
#  Repository(full_name="sayakpaul/robustness-foundation-models"),
#  Repository(full_name="sayakpaul/robustness-vit"),
#  Repository(full_name="sayakpaul/Scraping-DataCamp-Courses-and-Projects"),
#  Repository(full_name="sayakpaul/ServiceListAggregatorAndDifferentiator"),
#  Repository(full_name="sayakpaul/Sharpness-Aware-Minimization-TensorFlow"),
#  Repository(full_name="sayakpaul/SimCLR-in-TensorFlow-2"),
#  Repository(full_name="sayakpaul/Simple-MVC-Application-with-Java-EE"),
#  Repository(full_name="sayakpaul/SimpleWebScrapperInJava"),
#  Repository(full_name="sayakpaul/SimSiam-TF"),
#  Repository(full_name="sayakpaul/Spatial-Transformer-Networks-with-Keras"),
#  Repository(full_name="sayakpaul/stable-diffusion-keras-ft"),
#  Repository(full_name="sayakpaul/Stock_Insights"),
#  Repository(full_name="sayakpaul/Supervised-Contrastive-Learning-in-TensorFlow-2"),
#  Repository(full_name="sayakpaul/swin-transformers-tf"),
#  Repository(full_name="sayakpaul/TalksGiven"),
#  Repository(full_name="sayakpaul/TF-2.0-Hacks"),
#  Repository(full_name="sayakpaul/tf.keras-Distributed-Training"),
#  Repository(full_name="sayakpaul/Training-BatchNorm-and-Only-BatchNorm"),
#  Repository(full_name="sayakpaul/Transfer-Learning-with-CIFAR10"),
#  Repository(full_name="sayakpaul/tSNE-on-NSL_KDD"),
#  Repository(full_name="sayakpaul/Vehicle-Number-Plate-Detection"),
#  Repository(full_name="sayakpaul/vision-transformers-tf"),
#  Repository(full_name="sayakpaul/ViT-jax2tf"),
#  Repository(full_name="sayakpaul/xla-benchmark-sd"),
#  Repository(full_name="sayakpaul/you-dont-know-tensorflow"),
#  Repository(full_name="sayakpaul/zs-hiring-challenge")]

# %% [markdown]
# # Extract source codes and save in CSV
#
# The following code snippet works in the following manner:
#
# 1. Get list of files (*.py and *.ipynb) in the target repositories (`target_repos`)
# 2. Grasp the content of each file and decode it with `base64`
#   - for `*.py`, plain text will be extracted
#   - for `*.ipynb`, the contents of all the code cells will be extracted and merged as a single string (we will use a heuristic to filter the code cell involving shell commands and others)
# 3. Create a `pd.DataFrame` of `["reponame", "filepath", "content"]` column to store repository, filepath, and the extracted content
# 4. Iterate 1 ~ 3 steps for all target repositories, and append DataFrame to `df` which contains all records

# %%
target_repos = {
    "sayakpaul": [
        "Dual-Deployments-on-Vertex-AI",
        "Dual-Deployments-on-Vertex-AI",
        "CI-CD-for-Model-Training",
    ],
    "deep-diver": [
        "Continuous-Adaptation-for-Machine-Learning-System-to-Data-Changes",
        "semantic-segmentation-ml-pipeline",
        "mlops-hf-tf-vision-models",
    ],
}[USERNAME]

# %%
import base64
import pandas as pd
from nbformat import reads, NO_CONVERT
from github import GithubException

df = pd.DataFrame(columns=["reponame", "filepath", "content"])


def get_py_files(repo, file_list, path="."):
    """Fetches Python scripts and the notebooks for a given repo."""
    contents = repo.get_contents("")
    while contents:
        file_content = contents.pop(0)
        if file_content.type == "dir":
            contents.extend(repo.get_contents(file_content.path))
        else:
            if file_content.name.endswith("py"):
                file_list.append(file_content)
            elif file_content.name.endswith("ipynb"):
                file_list.append(file_content)


def filter_code_cell(cell):
    """Filters a code cell w.r.t shell commands, etc."""
    only_shell = cell["source"].startswith("!")
    only_magic = "%%capture" in cell["source"]
    if only_shell or only_magic:
        return False
    else:
        return True


for repo in repos:
    if repo.name in target_repos:
        file_list = []
        get_py_files(repo, file_list)

        if len(file_list) != 0:
            for file in file_list:
                if file.name.endswith("py"):
                    content = file.content
                    content_str = base64.b64decode(content).decode("utf-8")

                    if content != "":
                        df = pd.concat(
                            [
                                df,
                                pd.DataFrame.from_dict(
                                    [
                                        {
                                            "reponame": f"{USERNAME}/{repo.name}",
                                            "filepath": file.path,
                                            "content": content_str,
                                        }
                                    ]
                                ),
                            ]
                        )
                elif file.name.endswith("ipynb"):
                    content = file.content
                    content_str = base64.b64decode(content).decode("utf-8")

                    code_cell_str = ""
                    notebook = reads(content_str, NO_CONVERT)

                    code_cells = [
                        c
                        for c in notebook["cells"]
                        if c["cell_type"] == "code"
                        if filter_code_cell(c)
                    ]

                    for cell in code_cells:
                        code_cell_str += cell["source"]

                    if content != "":
                        df = pd.concat(
                            [
                                df,
                                pd.DataFrame.from_dict(
                                    [
                                        {
                                            "reponame": f"{USERNAME}/{repo.name}",
                                            "filepath": file.path,
                                            "content": code_cell_str,
                                        }
                                    ]
                                ),
                            ]
                        )
# Out:
# /usr/local/lib/python3.10/dist-packages/nbformat/__init__.py:93: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)

# %%
df.head()
# Out:
#                              reponame                       filepath  \
# 0  sayakpaul/CI-CD-for-Model-Training          cloud_build_tfx.ipynb
# 0  sayakpaul/CI-CD-for-Model-Training   cloud_function_trigger.ipynb
# 0  sayakpaul/CI-CD-for-Model-Training  cloud_scheduler_trigger.ipynb
# 0  sayakpaul/CI-CD-for-Model-Training      build/compile_pipeline.py
# 0  sayakpaul/CI-CD-for-Model-Training       build/create_pipeline.py
#
#                                              content
# 0  from google.colab import auth\nauth.authentica...
# 0  from google.colab import auth\nauth.authentica...
# 0  # only need if you are using Colab\nfrom googl...
# 0  import argparse\n\nfrom absl import logging\nf...
# 0  from tfx.orchestration import data_types\nfrom...

# %% [markdown]
# ### Save the resuling `DataFrame` to CSV

# %%
df.to_csv(f"{USERNAME}.csv")

# %% [markdown]
# ## Prepare a 🤗 Datasets compatible dataset

# %%
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.7 MB/s eta 0:00:00

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(df)
dataset
# Out:
# Dataset({
#     features: ['reponame', 'filepath', 'content', '__index_level_0__'],
#     num_rows: 18
# })

# %%
dataset = dataset.remove_columns(["__index_level_0__"])
dataset
# Out:
# Dataset({
#     features: ['reponame', 'filepath', 'content'],
#     num_rows: 18
# })

# %%
dataset[13]
# Out:
# {'reponame': 'sayakpaul/Dual-Deployments-on-Vertex-AI',
#  'filepath': 'custom_components/vertex_uploader.py',
#  'content': '"""\nCustom TFX component for importing a model into Vertex AI.\nAuthor: Sayak Paul\nReference: https://github.com/GoogleCloudPlatform/mlops-with-vertex-ai/blob/main/src/tfx_pipelines/components.py#L74\n"""\n\nimport os\nimport tensorflow as tf\n\nfrom tfx.dsl.component.experimental.decorators import component\nfrom tfx.dsl.component.experimental.annotations import Parameter\nfrom tfx.types.standard_artifacts import String\nfrom google.cloud import aiplatform as vertex_ai\nfrom tfx import v1 as tfx\nfrom absl import logging\n\n\n@component\ndef VertexUploader(\n    project: Parameter[str],\n    region: Parameter[str],\n    model_display_name: Parameter[str],\n    pushed_model_location: Parameter[str],\n    serving_image_uri: Parameter[str],\n    uploaded_model: tfx.dsl.components.OutputArtifact[String],\n):\n\n    vertex_ai.init(project=project, location=region)\n\n    pushed_model_dir = os.path.join(\n        pushed_model_location, tf.io.gfile.listdir(pushed_model_location)[-1]\n    )\n\n    logging.info(f"Model registry location: {pushed_model_dir}")\n\n    vertex_model = vertex_ai.Model.upload(\n        display_name=model_display_name,\n        artifact_uri=pushed_model_dir,\n        serving_container_image_uri=serving_image_uri,\n        parameters_schema_uri=None,\n        instance_schema_uri=None,\n        explanation_metadata=None,\n        explanation_parameters=None,\n    )\n\n    uploaded_model.set_string_custom_property(\n        "model_resource_name", str(vertex_model.resource_name)\n    )\n    logging.info(f"Model resource: {str(vertex_model.resource_name)}")\n'}

# %%
# !huggingface-cli login

# %%
dataset.push_to_hub("coding-assistant-custom/dummy-dataset-sayak")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
